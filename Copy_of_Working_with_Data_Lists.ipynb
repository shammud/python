# %% [markdown]
# <a href="https://colab.research.google.com/github/shammud/python/blob/main/Copy_of_Working_with_Data_Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lists
#
# Often we need to store a number of single items of data together so that they can be processed together. This might be because all the data refers to one person (e.g. name, age, gender, etc) OR it might be because we have a set of data (e.g. all the items that should be displayed in a drop down list, such as all the years from this year back to 100 years ago so that someone can select their year of birth)
#
# Python has a range of data structures available including:
# *   lists
# *   tuples
# *   dictionaries
# *   sets
#
# This worksheet looks at lists.
#
# ## List
# A list is a set of related, individual data objects, that are indexed and can be processed as a whole, as subsets or as individual items.  Lists are stored, essentially, as contiguous items in memory so that access can be as quick as possible.  However, they are mutable (they can be changed after they have been created and stored) and so they need to have extra functionality to deal with changing list sizes.
#
# # Let's get some lists of data
# For this worksheet we are going to work with data on STEAM games.  We are going to get the data from a spreadsheet and make lists that we can find things out from.

# %% [markdown]
# # Creating a list
# ```
# nums = [1, 2, 3, 4, 5]
# names = ["Tom","Jerry","Spike"]
# ```

# %% [markdown]
# # Printing a list
#
# ```
# print(nums)
# [1,2,3,4,5]
# ```
#
# ```
# print(names)
# ["Tom","Jerry","Spike"]
# ```

# %%
# create the lists, and print them
nums = [1,2,3,4,5]
names = ["Tom", "Jerry", "Spike"]
print(nums)
print(names)
# Out:
# [1, 2, 3, 4, 5]
# ['Tom', 'Jerry', 'Spike']

# %% [markdown]
# # Print individual items in the list
#
# We can access any item in a list by its position (index).  Lists are indexed from 0.
#
# To print the first item in a list, use listname[0], to print the last item use listname[-1].
#
# ```
# # This is formatted as code
# ```
#
#
#
# ```
# print(nums[0])
# 1
# ```
# ```
# print(names[1])
# Jerry
# ```
#
# ```
# print(nums[-1])
# 5
# ```

# %%
# have a go at printing different items from the lists
print(nums[0])
print(names[1])
print(nums[-1])
# Out:
# 1
# Jerry
# 5

# %% [markdown]
# # Print a subset of a list
#
# listname[start_index : end_index+1]
# If start_index is the first item, or end_index is the end of the list, they can be left out
#
# ```
# print(nums[:3])
# [1,2,3]
# ```
#
# ```
# print(names[1:])
# ["Jerry","Spike"]
# ```
#
# ```
# print(nums[1:3])
# [2,3]
# ```

# %%
# have a go at printing subsets of the lists
print(nums[:3])
print(names[1:])
print(nums[1:3])
# Out:
# [1, 2, 3]
# ['Jerry', 'Spike']
# [2, 3]

# %% [markdown]
# # List length
#
# Use the len() function to get the number of items in a list.
#
# There are 5 items in the nums list and 3 in the names list.
#
# Write a function that will:
# * print the length of the nums list
# * print the length of the names list
# * concatenate (add) the two lists together to make a new list called num_names
# * print the length of the new list
#
# Expected output:
# ```
# The length of the nums list is: 5
# The length of the names list is: 3
# The length of the joined list is: 8
# ```

# %%
def print_list_info():
  print("The length of the nums list is:", len(nums))
  print("The length of the names list is:", len(names))
  nums_names = nums + names
  print("The length of the joined list is:", len(nums_names))

print_list_info()
# Out:
# The length of the nums list is: 5
# The length of the names list is: 3
# The length of the joined list is: 8

# %% [markdown]
# # List methods
#
# You can get an overview of the methods you can use here: https://www.w3schools.com/python/python_lists_methods.asp
#
# Then:
# 1.  Create the nums and names list again
# 2.  Append the number 6 to the nums list, and print
# 3.  Insert the name "Sylvester" before "Jerry" in the names list and print
# 4.  Print the length of the nums list
# 5.  Remove the number 4 from the nums list, and print
# 6.  Print the max and min of the nums list
# 7.  Create a new list called new_nums which contains the numbers 40 to 50 (use the range function)
#
# Expected output:

# %%
nums = [1,2,3,4,5]
names = ["Tom", "Jerry","Spike"]
nums.append(6)
print(nums)
names.insert(1, "Sylvester")
print(names)
print(len(nums))
nums.remove(4)
print(nums)
print(max(nums), min(nums))
new_nums = range(40,51)
print(new_nums)
# Out:
# [1, 2, 3, 4, 5, 6]
# ['Tom', 'Sylvester', 'Jerry', 'Spike']
# 6
# [1, 2, 3, 5, 6]
# 6 1
# range(40, 51)

# %% [markdown]
# # Now some real data
# ---
#
# 1.  Open the STEAM csv file (which we have taken from Kaggle and have reduced to make it more manageable): https://drive.google.com/file/d/1rkG8-cp-KLBc1zK4YMLHIsMMyyTVk5Ju/view?usp=sharing
#
#
# 2.  Open the file with Google sheets to see what is in it.  The file contains rows of data, each with a user id and a game that the user has purchased.
#
# 3.  NOW, run the code in the cell below to get:
# - users (the list of user ids in the data)
# - titles (the list of titles that have been purchased)

# %%
import pandas as pd

# open the data file and get a copy of the Titles column
def get_users_and_titles():
  url = "https://drive.google.com/uc?export=download&id=1rkG8-cp-KLBc1zK4YMLHIsMMyyTVk5Ju"
  data_table = pd.read_csv(url)
  return data_table["User"].tolist(), data_table["Title"].tolist() 

users, titles = get_users_and_titles()

# %% [markdown]
# ---
# ### Exercise 1 - list head, tail and length of the titles list
# ---
#
# Write a function, **describe_list()** which will:
# *  print the length of the list `titles`
# *  print the first 10 items in `titles` (the head)
# *  print the last 5 items in `titles` (the tail)
#
# Expected output:
# ```
# 129511
# ['The Elder Scrolls V Skyrim', 'Fallout 4', 'Spore', 'Fallout New Vegas', 'Left 4 Dead 2', 'HuniePop', 'Path of Exile', 'Poly Bridge', 'Left 4 Dead', 'Team Fortress 2']
# ['Fallen Earth', 'Magic Duels', 'Titan Souls', 'Grand Theft Auto Vice City', 'RUSH']
# ```

# %%
def print_info():
  print(len(titles))
  print(titles[0:9])
  print(titles[-5:-1])               

print_info()
# Out:
# 129511
# ['The Elder Scrolls V Skyrim', 'Fallout 4', 'Spore', 'Fallout New Vegas', 'Left 4 Dead 2', 'HuniePop', 'Path of Exile', 'Poly Bridge', 'Left 4 Dead']
# ['Fallen Earth', 'Magic Duels', 'Titan Souls', 'Grand Theft Auto Vice City']

# %% [markdown]
# ---
# ### Exercise 2 - use a loop to print the first 20 items
#
# Write a function which will:
# *  create a new list from the first 20 items of the titles list
# *  loop through the new list and print each item

# %%
def print_list():
  new_list=[]
  for x in range(0,20):
    new_list.append(titles[x])
  print(new_list)
  

print_list()
# Out:
# ['The Elder Scrolls V Skyrim', 'Fallout 4', 'Spore', 'Fallout New Vegas', 'Left 4 Dead 2', 'HuniePop', 'Path of Exile', 'Poly Bridge', 'Left 4 Dead', 'Team Fortress 2', 'Tomb Raider', 'The Banner Saga', 'Dead Island Epidemic', 'BioShock Infinite', 'Dragon Age Origins - Ultimate Edition', 'Fallout 3 - Game of the Year Edition', 'SEGA Genesis & Mega Drive Classics', 'Grand Theft Auto IV', 'Realm of the Mad God', 'Marvel Heroes 2015']

# %% [markdown]
# ---
# ### Exercise 3 - count the number of times a title appears in the list
#
# Write a function which will:
# *  count the number of times that the title Fallout 4 appears in the list
#
# Expected output:
# 168

# %%
def count_title():
 print(titles.count("Fallout 4"))

count_title()
# Out:
# 168

# %% [markdown]
# ---
# ### Exercise 4 - remove all duplicates of a title from the list
#
# Write a function which will: remove all occurences of Fallout 4 from the titles list (Hint:  you can remove an occurence of Fallout 4 repeatedly until there is only one left)

# %%
def remove_duplicates():
  while ("Fallout4" in titles):
    titles.remove("Fallout4")
  print(len(titles))




remove_duplicates()
# Out:
# 129511

# %% [markdown]
# ---
# ### Exercise 5 - print the counts of the first 10 titles in the list
#
# Write a function which will:
# * loop through the first 10 items in the titles list
# * for each item print the number of times that title appears in the list

# %%
def print_count_of_first_ten():
 for i in titles[0:10]:
   #print(i)
   print(i," : ",titles.count(i))

users, titles = get_users_and_titles()
print_count_of_first_ten()
# Out:
# The Elder Scrolls V Skyrim  :  717
# Fallout 4  :  168
# Spore  :  67
# Fallout New Vegas  :  337
# Left 4 Dead 2  :  951
# HuniePop  :  22
# Path of Exile  :  339
# Poly Bridge  :  12
# Left 4 Dead  :  281
# Team Fortress 2  :  2323

# %% [markdown]
# ---
# ### Project - work as a team
#
# The users list has the ids of all the users who have purchased STEAM games.
#
# Write a function that will:
# * count how many games have been purchased by each user.
# * calculate the percentage of all purchases made by each user
# * calculate the percentage of all purchases made by these 100 users altogether
# * find the id of the user who has purchased the most games of these 100 users
# * calculate the average number of games purchased by a user from the 100
# * print this information, printing each unique user just once
# Do the same with the last 100 users
#
# Divide up the tasks and each write one part, then try to get them all to work together.

# %% [markdown]
# ### Practice 1
# ---
# Get a list of unique user ids
#
# Write some code that will loop through the users list and add each new user id to a new list called **unique_users**
#
# **Expected output**:
# 12393

# %%
# get list of unique user ids
def get_unique_users():
  unique_users=[]
  for i in users:
      if i not in unique_users:
        unique_users.append(i)
  print(len(unique_users))
  print(unique_users[0:2])
  return unique_users

unique_users=get_unique_users()
# Out:
# 12393
# [151603712, 187131847]

# %% [markdown]
# ### Practice 2
# ---
#
# Write code that will create a subset of the unique_users list, containing just the first 100 users and called **hundred_users**.  Loop through the hundred_users list and for each, will print the number of games that user has purchased (`users.count(unique_user`)
#
# **Expected output**:
# ```
# 40
# 1
# 43
# 505
# 1
# ...
# ...
# 2
# 18
# 27
# 1
# 33
# ```

# %%
# print number of games purchased by each of first hundred users
def sub_set():
  hundred_users=[]
  for i in range(0,100):
    hundred_users.append(unique_users[i])
  print(len(hundred_users))
  print(hundred_users[0:2])
  for user in hundred_users:
    print(users.count(user))

  return hundred_users

hundred_users=sub_set()
# Out:
# 100
# [151603712, 187131847]
# 40
# 1
# 43
# 505
# 1
# 1
# 10
# 1
# 1
# 1
# 1
# 1
# 3
# 1
# 3
# 1
# 29
# 1
# 2
# 2
# 1
# 1
# 1
# 4
# 2
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 67
# 5
# 1
# 1
# 1
# 11
# 1
# 2
# 2
# 6
# 1
# 1
# 15
# 13
# 2
# 8
# 6
# 127
# 1
# 1
# 4
# 458
# 1
# 2
# 2
# 31
# 1
# 4
# 16
# 1
# 1
# 1
# 6
# 11
# 1
# 1
# 22
# 1
# 1
# 1
# 3
# 5
# 1
# 1
# 2
# 1
# 4
# 3
# 1
# 1
# 1
# 1
# 1
# 2
# 5
# 4
# 1
# 1
# 6
# 2
# 9
# 3
# 4
# 2
# 18
# 27
# 1
# 33

# %% [markdown]
# ### Practice 3
# ---
# Write code to calculate the percentage that the first user in the unique_user list has purchased of all the purchases made by users.  Print the users id and the percentage
#
# *Hint*:  get the count for that user (as in the last practice), divide it by the number of purchase made (the length of the original users list) and multiply by 100
#
# **Expected output**:
# `151603712 0.03 %`

# %%
# Find percentage purchases bought by first user
print("user_id : ",unique_users[0])
print("count : ",users.count(unique_users[0]))
average=(count/len(users))*100
print("average : ",round(average,2),"%")
# Out:
# user_id :  151603712
# count :  40
# average :  0.03 %

# %% [markdown]
# ### Practice 4
# ---
# Write some code that will loop through the `hundred_users` and find the id of the user with the largest number of purchases
#
# **Expected output**:
# ```
# 53875128
# ```

# %%
# find user who has made most purchase
def large_purchases():
  most_common=hundred_users[0]
  frequency=users.count(most_common)
  for user in hundred_users:
    if users.count(user) > frequency:
      most_common=user
      frequency=users.count(user)
  print("Largest purchase id : ",most_common)
  print("Number of items : ",frequency)
large_purchases()
# Out:
# Largest purchase id :  53875128
# Number of items :  505

# %% [markdown]
# ### Practice 5
# ---
# Write some code that will loop through the `hundred_users`, add all the purchases made by them, then calculate this as a percentage of the total number of purchases made (as before)  divide by 100 (the number of users in this list) to get the average.
#
# **Expected output**:
# ```
# 0.01 %
#
# ```

# %%
# find percentage of total purchases made by first hundred users
a=0
for user in hundred_users:
    count=users.count(user)
    a=a+count
avg=((a/len(users))*100)/100
print("average : ",round(avg,2),"%")
# Out:
# average :  0.01 %

# %% [markdown]
# ### Practice 6
# ---
#
# Write some code that will loop through the `hundred_users`, add all the purchases made by them, then divide by 100 (the number of users in this list) to get the average.
#
# **Expected output**:
# ```
# 16.46
#
# ```

# %%
# find average number of purchases made by first 100 users
def avg_hundred_users():
  a=0
  for user in hundred_users:
    count=users.count(user)
    a=a+count
average = (a/len(hundred_users))
print("average : ",average)
# Out:
# average :  16.46

# %% [markdown]
# ### Practice 7
# ---
# Put all the above together into a function, and add code to print the average number of games per user, the user id of the user with the maximum number of purchases, and a list of the hundred users ids and the percentage each has purchased

# %%
def process_user_purchases():
#user with maximum number of purchase
  count=0
temp=0
index=0
for x in range(0,len(users)):
  temp=users.count(users[x])
  if temp > count:
    count=temp
    index=x
a=users[index]
print("user_id : ",a)
print("Number of items : ",count)

#list of hundred user id and percentage :
for i in range(0,len(hundred_users)):
   print("user_id : ",hundred_users[i])
   total=users.count(hundred_users[i])
   print("total : ",total)
   average=(total/len(users))*100
   print("percentage : ",round(average,6),"%")
#average number of games per user
for i in range(0,len(unique_users)):
   total=users.count(unique_users[i])
   average=total/len(users)
   print("user_id: ",unique_users[i],"  average : ",round(average,5))


process_user_purchases()
# Out:
# Streaming output truncated to the last 5000 lines.
# user_id:  76027799   average :  8e-05
# user_id:  113820072   average :  1e-05
# user_id:  194678830   average :  1e-05
# user_id:  216924034   average :  1e-05
# user_id:  141012357   average :  1e-05
# user_id:  192341303   average :  5e-05
# user_id:  20704366   average :  0.00023
# user_id:  60227446   average :  4e-05
# user_id:  299025375   average :  2e-05
# user_id:  25822628   average :  5e-05
# user_id:  105517470   average :  2e-05
# user_id:  181262663   average :  1e-05
# user_id:  101695880   average :  0.0007
# user_id:  99110207   average :  8e-05
# user_id:  48798067   average :  0.00308
# user_id:  122471552   average :  2e-05
# user_id:  304788598   average :  1e-05
# user_id:  126063949   average :  1e-05
# user_id:  276073724   average :  2e-05
# user_id:  74270476   average :  1e-05
# user_id:  91567150   average :  1e-05
# user_id:  79626460   average :  1e-05
# user_id:  298367684   average :  1e-05
# user_id:  205253661   average :  1e-05
# user_id:  115375178   average :  1e-05
# user_id:  300729671   average :  1e-05
# user_id:  21683270   average :  3e-05
# user_id:  48492052   average :  9e-05
# user_id:  273082868   average :  0.00019
# user_id:  215334587   average :  2e-05
# user_id:  161139120   average :  8e-05
# user_id:  193196975   average :  0.00015
# user_id:  90857581   average :  3e-05
# user_id:  187115070   average :  1e-05
# user_id:  200321746   average :  2e-05
# user_id:  148413660   average :  1e-05
# user_id:  77261379   average :  1e-05
# user_id:  63831340   average :  1e-05
# user_id:  205829374   average :  4e-05
# user_id:  82203951   average :  0.00011
# user_id:  277782286   average :  1e-05
# user_id:  3450426   average :  6e-05
# user_id:  105511340   average :  1e-05
# user_id:  184385867   average :  5e-05
# user_id:  257518188   average :  1e-05
# user_id:  69729762   average :  1e-05
# user_id:  62990992   average :  0.0083
# user_id:  106054679   average :  3e-05
# user_id:  31944667   average :  5e-05
# user_id:  65962952   average :  2e-05
# user_id:  109780632   average :  9e-05
# user_id:  173447731   average :  1e-05
# user_id:  250955812   average :  1e-05
# user_id:  56157984   average :  1e-05
# user_id:  218478781   average :  1e-05
# user_id:  279316312   average :  3e-05
# user_id:  133228469   average :  8e-05
# user_id:  179279152   average :  1e-05
# user_id:  57782416   average :  3e-05
# user_id:  290542222   average :  8e-05
# user_id:  251920440   average :  2e-05
# user_id:  204702638   average :  2e-05
# user_id:  207186541   average :  0.00012
# user_id:  239138885   average :  1e-05
# user_id:  245046657   average :  1e-05
# user_id:  260057593   average :  1e-05
# user_id:  151817681   average :  1e-05
# user_id:  96648859   average :  1e-05
# user_id:  104235320   average :  1e-05
# user_id:  254924405   average :  1e-05
# user_id:  205424925   average :  4e-05
# user_id:  89564754   average :  2e-05
# user_id:  53122638   average :  1e-05
# user_id:  21316693   average :  0.00013
# user_id:  286657812   average :  1e-05
# user_id:  102540721   average :  1e-05
# user_id:  307639284   average :  1e-05
# user_id:  186213909   average :  1e-05
# user_id:  153390095   average :  1e-05
# user_id:  235290543   average :  2e-05
# user_id:  298516674   average :  1e-05
# user_id:  176103650   average :  8e-05
# user_id:  199466958   average :  1e-05
# user_id:  136291039   average :  1e-05
# user_id:  297108494   average :  1e-05
# user_id:  167184744   average :  1e-05
# user_id:  68828361   average :  1e-05
# user_id:  298236235   average :  1e-05
# user_id:  116338192   average :  1e-05
# user_id:  266799152   average :  4e-05
# user_id:  194506370   average :  1e-05
# user_id:  259403281   average :  3e-05
# user_id:  39322716   average :  0.0001
# user_id:  28113724   average :  5e-05
# user_id:  286511722   average :  1e-05
# user_id:  118991581   average :  2e-05
# user_id:  127218796   average :  1e-05
# user_id:  148264060   average :  0.00011
# user_id:  195436818   average :  1e-05
# user_id:  43551909   average :  1e-05
# user_id:  202921867   average :  4e-05
# user_id:  169937489   average :  9e-05
# user_id:  239021889   average :  1e-05
# user_id:  284165884   average :  1e-05
# user_id:  250429853   average :  2e-05
# user_id:  40280688   average :  0.00016
# user_id:  245078207   average :  0.00017
# user_id:  302742986   average :  1e-05
# user_id:  10302000   average :  0.00032
# user_id:  248235621   average :  1e-05
# user_id:  293349681   average :  1e-05
# user_id:  198309472   average :  1e-05
# user_id:  68952161   average :  1e-05
# user_id:  111498455   average :  0.00014
# user_id:  152929009   average :  1e-05
# user_id:  116437770   average :  2e-05
# user_id:  167749301   average :  2e-05
# user_id:  159077305   average :  0.00026
# user_id:  285085570   average :  1e-05
# user_id:  242694628   average :  8e-05
# user_id:  198744602   average :  1e-05
# user_id:  184250682   average :  1e-05
# user_id:  293244157   average :  2e-05
# user_id:  298182105   average :  1e-05
# user_id:  192645567   average :  3e-05
# user_id:  230944154   average :  0.00027
# user_id:  80799336   average :  3e-05
# user_id:  31124692   average :  2e-05
# user_id:  222050169   average :  0.00013
# user_id:  113196318   average :  0.00036
# user_id:  156343742   average :  2e-05
# user_id:  146841726   average :  2e-05
# user_id:  146762928   average :  5e-05
# user_id:  226428439   average :  1e-05
# user_id:  179518925   average :  1e-05
# user_id:  99484728   average :  4e-05
# user_id:  273069628   average :  4e-05
# user_id:  210114509   average :  1e-05
# user_id:  140223606   average :  1e-05
# user_id:  204742217   average :  8e-05
# user_id:  222986054   average :  1e-05
# user_id:  52181854   average :  3e-05
# user_id:  296449198   average :  1e-05
# user_id:  155858528   average :  1e-05
# user_id:  267235316   average :  7e-05
# user_id:  192201048   average :  1e-05
# user_id:  190074593   average :  7e-05
# user_id:  152078939   average :  0.00051
# user_id:  217734723   average :  1e-05
# user_id:  258648395   average :  1e-05
# user_id:  68173628   average :  1e-05
# user_id:  28229872   average :  5e-05
# user_id:  218844731   average :  2e-05
# user_id:  295693261   average :  2e-05
# user_id:  5307960   average :  6e-05
# user_id:  115637271   average :  2e-05
# user_id:  74126541   average :  5e-05
# user_id:  127058155   average :  1e-05
# user_id:  287613958   average :  1e-05
# user_id:  76892907   average :  0.00461
# user_id:  300449823   average :  1e-05
# user_id:  106333903   average :  0.00021
# user_id:  276820640   average :  1e-05
# user_id:  112566632   average :  1e-05
# user_id:  124975432   average :  1e-05
# user_id:  214805425   average :  3e-05
# user_id:  118433250   average :  1e-05
# user_id:  282599048   average :  1e-05
# user_id:  115487966   average :  0.00038
# user_id:  188425099   average :  1e-05
# user_id:  137951076   average :  2e-05
# user_id:  295981434   average :  7e-05
# user_id:  94862562   average :  1e-05
# user_id:  249550615   average :  2e-05
# user_id:  276520060   average :  2e-05
# user_id:  23072560   average :  3e-05
# user_id:  218600642   average :  1e-05
# user_id:  125875677   average :  5e-05
# user_id:  227901139   average :  1e-05
# user_id:  29268335   average :  4e-05
# user_id:  307998745   average :  1e-05
# user_id:  199236587   average :  5e-05
# user_id:  52583581   average :  1e-05
# user_id:  144731554   average :  1e-05
# user_id:  65754991   average :  0.0011
# user_id:  113546110   average :  0.00051
# user_id:  286394356   average :  1e-05
# user_id:  176811312   average :  1e-05
# user_id:  79865632   average :  4e-05
# user_id:  76047408   average :  1e-05
# user_id:  86779877   average :  2e-05
# user_id:  197656011   average :  1e-05
# user_id:  109486584   average :  2e-05
# user_id:  219095735   average :  1e-05
# user_id:  192609869   average :  1e-05
# user_id:  73017395   average :  1e-05
# user_id:  280363186   average :  5e-05
# user_id:  108454875   average :  9e-05
# user_id:  192052864   average :  1e-05
# user_id:  236182162   average :  1e-05
# user_id:  31425362   average :  4e-05
# user_id:  297136903   average :  1e-05
# user_id:  248754096   average :  4e-05
# user_id:  44321815   average :  0.00032
# user_id:  108714391   average :  3e-05
# user_id:  208680317   average :  1e-05
# user_id:  156639838   average :  2e-05
# user_id:  293693492   average :  1e-05
# user_id:  158693714   average :  1e-05
# user_id:  87753149   average :  5e-05
# user_id:  188699277   average :  2e-05
# user_id:  220157121   average :  1e-05
# user_id:  10450544   average :  0.00091
# user_id:  178098476   average :  1e-05
# user_id:  113835971   average :  2e-05
# user_id:  290864164   average :  1e-05
# user_id:  187807630   average :  1e-05
# user_id:  235105105   average :  1e-05
# user_id:  65173746   average :  8e-05
# user_id:  122452753   average :  1e-05
# user_id:  135690828   average :  1e-05
# user_id:  129862640   average :  1e-05
# user_id:  108327674   average :  1e-05
# user_id:  79211079   average :  0.00028
# user_id:  66215101   average :  2e-05
# user_id:  199709157   average :  2e-05
# user_id:  100916842   average :  5e-05
# user_id:  36557643   average :  0.00321
# user_id:  176021276   average :  1e-05
# user_id:  293364588   average :  1e-05
# user_id:  197385611   average :  4e-05
# user_id:  153828204   average :  1e-05
# user_id:  4603800   average :  8e-05
# user_id:  126231245   average :  1e-05
# user_id:  46028967   average :  0.00183
# user_id:  89618826   average :  1e-05
# user_id:  303615424   average :  2e-05
# user_id:  158866144   average :  1e-05
# user_id:  206510641   average :  5e-05
# user_id:  102539470   average :  2e-05
# user_id:  121481890   average :  1e-05
# user_id:  103705957   average :  1e-05
# user_id:  58431944   average :  0.0003
# user_id:  47332601   average :  2e-05
# user_id:  149386510   average :  1e-05
# user_id:  208464394   average :  5e-05
# user_id:  64023574   average :  0.00066
# user_id:  68532738   average :  0.00017
# user_id:  259325175   average :  2e-05
# user_id:  89856899   average :  1e-05
# user_id:  204412693   average :  1e-05
# user_id:  180063157   average :  1e-05
# user_id:  280609756   average :  1e-05
# user_id:  36288200   average :  1e-05
# user_id:  206494852   average :  3e-05
# user_id:  241929529   average :  1e-05
# user_id:  255027745   average :  1e-05
# user_id:  70591968   average :  8e-05
# user_id:  234348805   average :  5e-05
# user_id:  156748261   average :  5e-05
# user_id:  187966424   average :  1e-05
# user_id:  50572608   average :  3e-05
# user_id:  80239919   average :  0.00015
# user_id:  161504500   average :  1e-05
# user_id:  199647568   average :  1e-05
# user_id:  186762233   average :  1e-05
# user_id:  168082750   average :  3e-05
# user_id:  308165484   average :  1e-05
# user_id:  182280948   average :  2e-05
# user_id:  207515194   average :  1e-05
# user_id:  90711776   average :  0.00023
# user_id:  130941814   average :  1e-05
# user_id:  3614782   average :  0.00011
# user_id:  29537499   average :  2e-05
# user_id:  34863766   average :  3e-05
# user_id:  173469318   average :  1e-05
# user_id:  129762577   average :  1e-05
# user_id:  114736887   average :  2e-05
# user_id:  220640317   average :  2e-05
# user_id:  295885446   average :  1e-05
# user_id:  205633955   average :  1e-05
# user_id:  59818635   average :  2e-05
# user_id:  232947963   average :  1e-05
# user_id:  59159042   average :  1e-05
# user_id:  203133963   average :  1e-05
# user_id:  101719689   average :  5e-05
# user_id:  49718752   average :  1e-05
# user_id:  64158475   average :  1e-05
# user_id:  101212067   average :  0.00015
# user_id:  125508547   average :  1e-05
# user_id:  129724065   average :  1e-05
# user_id:  253121356   average :  6e-05
# user_id:  64261708   average :  0.0001
# user_id:  36775354   average :  5e-05
# user_id:  85395339   average :  2e-05
# user_id:  209340839   average :  5e-05
# user_id:  108484523   average :  2e-05
# user_id:  248757796   average :  2e-05
# user_id:  35227774   average :  8e-05
# user_id:  167118460   average :  0.0003
# user_id:  80154824   average :  2e-05
# user_id:  112677705   average :  2e-05
# user_id:  9740704   average :  8e-05
# user_id:  207365563   average :  3e-05
# user_id:  264496864   average :  1e-05
# user_id:  242112520   average :  6e-05
# user_id:  165877735   average :  2e-05
# user_id:  240278903   average :  1e-05
# user_id:  209120214   average :  1e-05
# user_id:  121137382   average :  1e-05
# user_id:  159377740   average :  1e-05
# user_id:  200059104   average :  0.00021
# user_id:  307729778   average :  2e-05
# user_id:  250492644   average :  2e-05
# user_id:  156733822   average :  4e-05
# user_id:  278757028   average :  1e-05
# user_id:  165210999   average :  2e-05
# user_id:  246386712   average :  1e-05
# user_id:  52203520   average :  8e-05
# user_id:  116515529   average :  2e-05
# user_id:  129128224   average :  1e-05
# user_id:  129743598   average :  1e-05
# user_id:  276555062   average :  2e-05
# user_id:  68017342   average :  1e-05
# user_id:  151724188   average :  1e-05
# user_id:  19696244   average :  0.00085
# user_id:  207424334   average :  8e-05
# user_id:  112999066   average :  1e-05
# user_id:  223614273   average :  2e-05
# user_id:  186126772   average :  5e-05
# user_id:  177446373   average :  1e-05
# user_id:  48395915   average :  1e-05
# user_id:  188615226   average :  4e-05
# user_id:  160461131   average :  5e-05
# user_id:  161964288   average :  1e-05
# user_id:  280567820   average :  1e-05
# user_id:  270228556   average :  1e-05
# user_id:  270341392   average :  1e-05
# user_id:  250375228   average :  5e-05
# user_id:  27770064   average :  3e-05
# user_id:  306636026   average :  1e-05
# user_id:  25827559   average :  5e-05
# user_id:  198398830   average :  6e-05
# user_id:  281041560   average :  1e-05
# user_id:  186273988   average :  1e-05
# user_id:  86612326   average :  4e-05
# user_id:  46405162   average :  5e-05
# user_id:  79163006   average :  1e-05
# user_id:  174716026   average :  1e-05
# user_id:  122319388   average :  3e-05
# user_id:  135338821   average :  2e-05
# user_id:  258381465   average :  2e-05
# user_id:  189344955   average :  1e-05
# user_id:  169815221   average :  1e-05
# user_id:  165382705   average :  1e-05
# user_id:  226354893   average :  1e-05
# user_id:  82385352   average :  0.00029
# user_id:  282502466   average :  1e-05
# user_id:  186452037   average :  2e-05
# user_id:  181638799   average :  0.00013
# user_id:  247741393   average :  1e-05
# user_id:  32415191   average :  5e-05
# user_id:  92250668   average :  2e-05
# user_id:  251285557   average :  2e-05
# user_id:  143669519   average :  1e-05
# user_id:  124400480   average :  0.00017
# user_id:  278136010   average :  4e-05
# user_id:  145890520   average :  1e-05
# user_id:  239511574   average :  7e-05
# user_id:  75515543   average :  1e-05
# user_id:  115249917   average :  1e-05
# user_id:  185435886   average :  2e-05
# user_id:  305037794   average :  1e-05
# user_id:  188266554   average :  0.0001
# user_id:  125249652   average :  1e-05
# user_id:  20557028   average :  3e-05
# user_id:  105934631   average :  1e-05
# user_id:  303467308   average :  5e-05
# user_id:  201275304   average :  1e-05
# user_id:  64778733   average :  1e-05
# user_id:  308851621   average :  1e-05
# user_id:  218448119   average :  1e-05
# user_id:  114912926   average :  5e-05
# user_id:  298071662   average :  1e-05
# user_id:  161408431   average :  1e-05
# user_id:  94751685   average :  1e-05
# user_id:  274624060   average :  2e-05
# user_id:  179560117   average :  1e-05
# user_id:  140492549   average :  1e-05
# user_id:  254565281   average :  2e-05
# user_id:  115996656   average :  0.0007
# user_id:  190861612   average :  1e-05
# user_id:  36757524   average :  2e-05
# user_id:  224586627   average :  1e-05
# user_id:  176810372   average :  2e-05
# user_id:  251656719   average :  2e-05
# user_id:  63895034   average :  9e-05
# user_id:  88152309   average :  0.0001
# user_id:  164663996   average :  2e-05
# user_id:  78765966   average :  2e-05
# user_id:  23241240   average :  4e-05
# user_id:  300305800   average :  1e-05
# user_id:  298507313   average :  1e-05
# user_id:  166048025   average :  8e-05
# user_id:  208140106   average :  1e-05
# user_id:  249643192   average :  4e-05
# user_id:  293714386   average :  1e-05
# user_id:  92010366   average :  3e-05
# user_id:  250414887   average :  2e-05
# user_id:  176453461   average :  1e-05
# user_id:  197057442   average :  2e-05
# user_id:  205549354   average :  2e-05
# user_id:  263454788   average :  1e-05
# user_id:  282896672   average :  1e-05
# user_id:  255892249   average :  1e-05
# user_id:  53324742   average :  1e-05
# user_id:  218608613   average :  2e-05
# user_id:  153772705   average :  1e-05
# user_id:  97250159   average :  1e-05
# user_id:  204679729   average :  5e-05
# user_id:  83746733   average :  0.00019
# user_id:  48921893   average :  2e-05
# user_id:  26593066   average :  3e-05
# user_id:  40837142   average :  4e-05
# user_id:  157047851   average :  1e-05
# user_id:  72471210   average :  2e-05
# user_id:  107488920   average :  1e-05
# user_id:  139873696   average :  2e-05
# user_id:  159865370   average :  2e-05
# user_id:  57424113   average :  8e-05
# user_id:  186323628   average :  5e-05
# user_id:  132748085   average :  0.00072
# user_id:  192170147   average :  0.00053
# user_id:  146704328   average :  1e-05
# user_id:  86620865   average :  1e-05
# user_id:  113580708   average :  0.00032
# user_id:  249779815   average :  3e-05
# user_id:  108435168   average :  2e-05
# user_id:  308406683   average :  1e-05
# user_id:  93350571   average :  1e-05
# user_id:  131912265   average :  3e-05
# user_id:  120448027   average :  1e-05
# user_id:  281552962   average :  1e-05
# user_id:  21580713   average :  5e-05
# user_id:  256297825   average :  1e-05
# user_id:  31063925   average :  2e-05
# user_id:  207510132   average :  1e-05
# user_id:  193029586   average :  3e-05
# user_id:  99374297   average :  0.00036
# user_id:  61779218   average :  0.00018
# user_id:  109592594   average :  8e-05
# user_id:  234064650   average :  2e-05
# user_id:  74989665   average :  2e-05
# user_id:  128792215   average :  1e-05
# user_id:  302437973   average :  2e-05
# user_id:  58967365   average :  1e-05
# user_id:  293231906   average :  1e-05
# user_id:  197070285   average :  1e-05
# user_id:  195946569   average :  0.00012
# user_id:  49228258   average :  0.00149
# user_id:  12423315   average :  5e-05
# user_id:  138279635   average :  7e-05
# user_id:  90033155   average :  0.00026
# user_id:  161540905   average :  1e-05
# user_id:  214019307   average :  1e-05
# user_id:  94690173   average :  4e-05
# user_id:  140337149   average :  1e-05
# user_id:  197190654   average :  0.00022
# user_id:  36349097   average :  5e-05
# user_id:  199423036   average :  2e-05
# user_id:  44755776   average :  0.00017
# user_id:  160055758   average :  2e-05
# user_id:  11504910   average :  3e-05
# user_id:  232027326   average :  1e-05
# user_id:  225178605   average :  1e-05
# user_id:  72555195   average :  1e-05
# user_id:  157104680   average :  1e-05
# user_id:  247828143   average :  1e-05
# user_id:  183490713   average :  0.0001
# user_id:  155752052   average :  1e-05
# user_id:  108011380   average :  1e-05
# user_id:  254196196   average :  2e-05
# user_id:  92612763   average :  0.00068
# user_id:  210018093   average :  7e-05
# user_id:  160649706   average :  1e-05
# user_id:  230321601   average :  1e-05
# user_id:  194800299   average :  1e-05
# user_id:  115167911   average :  0.00042
# user_id:  17556127   average :  2e-05
# user_id:  244936819   average :  1e-05
# user_id:  288385496   average :  1e-05
# user_id:  194432540   average :  0.00012
# user_id:  190721470   average :  1e-05
# user_id:  217968557   average :  2e-05
# user_id:  217539381   average :  1e-05
# user_id:  260813316   average :  1e-05
# user_id:  73754563   average :  1e-05
# user_id:  198584696   average :  1e-05
# user_id:  111182405   average :  0.00022
# user_id:  23432272   average :  3e-05
# user_id:  289759310   average :  2e-05
# user_id:  186344581   average :  6e-05
# user_id:  168754318   average :  2e-05
# user_id:  146979551   average :  2e-05
# user_id:  284934852   average :  4e-05
# user_id:  256216485   average :  2e-05
# user_id:  121199670   average :  2e-05
# user_id:  94865453   average :  2e-05
# user_id:  39028341   average :  3e-05
# user_id:  300757930   average :  1e-05
# user_id:  147795278   average :  1e-05
# user_id:  94231294   average :  3e-05
# user_id:  199013605   average :  2e-05
# user_id:  123423051   average :  1e-05
# user_id:  158447093   average :  1e-05
# user_id:  38523044   average :  2e-05
# user_id:  166899607   average :  1e-05
# user_id:  192031349   average :  2e-05
# user_id:  308327488   average :  1e-05
# user_id:  215022297   average :  1e-05
# user_id:  171846037   average :  1e-05
# user_id:  298666122   average :  1e-05
# user_id:  238169854   average :  3e-05
# user_id:  70737757   average :  3e-05
# user_id:  45532207   average :  7e-05
# user_id:  137075650   average :  1e-05
# user_id:  239318205   average :  1e-05
# user_id:  184493955   average :  2e-05
# user_id:  262814808   average :  4e-05
# user_id:  214281367   average :  2e-05
# user_id:  191979928   average :  0.00062
# user_id:  299037840   average :  2e-05
# user_id:  49624770   average :  0.00046
# user_id:  49629862   average :  5e-05
# user_id:  159371621   average :  0.00059
# user_id:  308468736   average :  2e-05
# user_id:  37468189   average :  2e-05
# user_id:  152956403   average :  0.00026
# user_id:  89524281   average :  1e-05
# user_id:  211899679   average :  1e-05
# user_id:  29753085   average :  0.00068
# user_id:  101240143   average :  1e-05
# user_id:  184568310   average :  1e-05
# user_id:  119937035   average :  0.00016
# user_id:  53296539   average :  1e-05
# user_id:  63454504   average :  2e-05
# user_id:  309903146   average :  1e-05
# user_id:  243077634   average :  2e-05
# user_id:  124725852   average :  0.00116
# user_id:  154940949   average :  0.00022
# user_id:  231026651   average :  0.00018
# user_id:  216217925   average :  8e-05
# user_id:  155071993   average :  8e-05
# user_id:  73521885   average :  2e-05
# user_id:  182592900   average :  1e-05
# user_id:  69821151   average :  3e-05
# user_id:  148528469   average :  1e-05
# user_id:  104900462   average :  1e-05
# user_id:  201023624   average :  2e-05
# user_id:  290225336   average :  1e-05
# user_id:  150903970   average :  1e-05
# user_id:  204147089   average :  2e-05
# user_id:  190628198   average :  2e-05
# user_id:  26808868   average :  0.00056
# user_id:  242351732   average :  1e-05
# user_id:  149150848   average :  1e-05
# user_id:  110209964   average :  1e-05
# user_id:  65341706   average :  2e-05
# user_id:  174342589   average :  2e-05
# user_id:  230028994   average :  1e-05
# user_id:  41846650   average :  7e-05
# user_id:  42198457   average :  0.00014
# user_id:  130758906   average :  2e-05
# user_id:  244480793   average :  1e-05
# user_id:  18500119   average :  0.00013
# user_id:  10599862   average :  0.00198
# user_id:  231805700   average :  4e-05
# user_id:  260376156   average :  0.00018
# user_id:  250238131   average :  0.0001
# user_id:  229405602   average :  1e-05
# user_id:  146796532   average :  1e-05
# user_id:  149711127   average :  1e-05
# user_id:  120725512   average :  1e-05
# user_id:  162735255   average :  1e-05
# user_id:  244992231   average :  1e-05
# user_id:  30588978   average :  4e-05
# user_id:  119556235   average :  2e-05
# user_id:  304395604   average :  1e-05
# user_id:  170275839   average :  2e-05
# user_id:  152567497   average :  1e-05
# user_id:  84371132   average :  2e-05
# user_id:  220306050   average :  1e-05
# user_id:  64027842   average :  8e-05
# user_id:  78969820   average :  1e-05
# user_id:  239348249   average :  1e-05
# user_id:  188713427   average :  2e-05
# user_id:  179001573   average :  1e-05
# user_id:  128335681   average :  1e-05
# user_id:  243808511   average :  3e-05
# user_id:  154330480   average :  1e-05
# user_id:  88579585   average :  0.00196
# user_id:  110226344   average :  4e-05
# user_id:  145027235   average :  1e-05
# user_id:  73435399   average :  1e-05
# user_id:  96536935   average :  2e-05
# user_id:  70915652   average :  0.00042
# user_id:  38436635   average :  5e-05
# user_id:  210190607   average :  1e-05
# user_id:  239937501   average :  1e-05
# user_id:  88100014   average :  1e-05
# user_id:  137732181   average :  1e-05
# user_id:  28236623   average :  3e-05
# user_id:  264047092   average :  2e-05
# user_id:  159812802   average :  4e-05
# user_id:  300759788   average :  1e-05
# user_id:  192109670   average :  1e-05
# user_id:  184576164   average :  2e-05
# user_id:  235358002   average :  1e-05
# user_id:  63539914   average :  2e-05
# user_id:  8817922   average :  5e-05
# user_id:  224352019   average :  1e-05
# user_id:  126718281   average :  2e-05
# user_id:  55691331   average :  1e-05
# user_id:  122620165   average :  0.00015
# user_id:  80988171   average :  0.0001
# user_id:  166547657   average :  1e-05
# user_id:  60236480   average :  6e-05
# user_id:  227844450   average :  1e-05
# user_id:  149233338   average :  1e-05
# user_id:  197987776   average :  1e-05
# user_id:  189020294   average :  1e-05
# user_id:  39911920   average :  5e-05
# user_id:  67341526   average :  1e-05
# user_id:  157906181   average :  1e-05
# user_id:  176967288   average :  3e-05
# user_id:  40051659   average :  7e-05
# user_id:  29052354   average :  0.00012
# user_id:  98848653   average :  0.00063
# user_id:  208467850   average :  1e-05
# user_id:  230031062   average :  7e-05
# user_id:  55672384   average :  3e-05
# user_id:  126992940   average :  0.00012
# user_id:  112376397   average :  0.00012
# user_id:  172386568   average :  1e-05
# user_id:  144652370   average :  1e-05
# user_id:  109446190   average :  1e-05
# user_id:  137623071   average :  1e-05
# user_id:  157003504   average :  1e-05
# user_id:  122956129   average :  7e-05
# user_id:  197876733   average :  2e-05
# user_id:  234785523   average :  1e-05
# user_id:  212790797   average :  2e-05
# user_id:  37727952   average :  5e-05
# user_id:  257200017   average :  2e-05
# user_id:  242985754   average :  4e-05
# user_id:  62885387   average :  1e-05
# user_id:  93203004   average :  1e-05
# user_id:  135244036   average :  0.00045
# user_id:  166234554   average :  1e-05
# user_id:  115109218   average :  2e-05
# user_id:  222042345   average :  3e-05
# user_id:  50888871   average :  3e-05
# user_id:  270356700   average :  0.00032
# user_id:  51941260   average :  6e-05
# user_id:  14962163   average :  0.00073
# user_id:  85136214   average :  1e-05
# user_id:  44153929   average :  9e-05
# user_id:  40080833   average :  0.00018
# user_id:  21539893   average :  0.00035
# user_id:  211363681   average :  1e-05
# user_id:  122162211   average :  1e-05
# user_id:  143006890   average :  1e-05
# user_id:  308178753   average :  1e-05
# user_id:  100359523   average :  5e-05
# user_id:  157141574   average :  1e-05
# user_id:  76170931   average :  1e-05
# user_id:  176024097   average :  1e-05
# user_id:  280317702   average :  1e-05
# user_id:  76451157   average :  0.00088
# user_id:  101777615   average :  1e-05
# user_id:  210961590   average :  1e-05
# user_id:  112547463   average :  5e-05
# user_id:  126796140   average :  7e-05
# user_id:  53509003   average :  8e-05
# user_id:  4812175   average :  6e-05
# user_id:  124810250   average :  4e-05
# user_id:  198901867   average :  4e-05
# user_id:  84079486   average :  1e-05
# user_id:  135929781   average :  1e-05
# user_id:  170535102   average :  1e-05
# user_id:  147764275   average :  1e-05
# user_id:  56014527   average :  2e-05
# user_id:  116000122   average :  1e-05
# user_id:  66550579   average :  1e-05
# user_id:  184173132   average :  1e-05
# user_id:  248882404   average :  0.00012
# user_id:  298381887   average :  1e-05
# user_id:  263042332   average :  1e-05
# user_id:  194993610   average :  1e-05
# user_id:  185494712   average :  6e-05
# user_id:  227246783   average :  1e-05
# user_id:  236191066   average :  1e-05
# user_id:  281302904   average :  1e-05
# user_id:  145512685   average :  0.00021
# user_id:  130247011   average :  1e-05
# user_id:  159114904   average :  0.00032
# user_id:  95347493   average :  2e-05
# user_id:  249871404   average :  1e-05
# user_id:  242287908   average :  1e-05
# user_id:  173194267   average :  1e-05
# user_id:  78481493   average :  1e-05
# user_id:  50131557   average :  3e-05
# user_id:  302089220   average :  1e-05
# user_id:  155036762   average :  2e-05
# user_id:  110470534   average :  8e-05
# user_id:  247951379   average :  1e-05
# user_id:  155818761   average :  1e-05
# user_id:  175738505   average :  1e-05
# user_id:  304251785   average :  1e-05
# user_id:  192772707   average :  0.00015
# user_id:  191937457   average :  1e-05
# user_id:  295039588   average :  2e-05
# user_id:  198107903   average :  2e-05
# user_id:  221823551   average :  2e-05
# user_id:  8784496   average :  0.00026
# user_id:  210921698   average :  1e-05
# user_id:  239211065   average :  1e-05
# user_id:  118723066   average :  9e-05
# user_id:  180438232   average :  3e-05
# user_id:  219593982   average :  1e-05
# user_id:  75753011   average :  2e-05
# user_id:  165526290   average :  1e-05
# user_id:  159647844   average :  1e-05
# user_id:  71868890   average :  1e-05
# user_id:  193230408   average :  1e-05
# user_id:  206764959   average :  1e-05
# user_id:  265054404   average :  1e-05
# user_id:  132757318   average :  1e-05
# user_id:  193693887   average :  1e-05
# user_id:  84377525   average :  1e-05
# user_id:  300892049   average :  1e-05
# user_id:  71302392   average :  1e-05
# user_id:  192482286   average :  1e-05
# user_id:  304674551   average :  1e-05
# user_id:  100353577   average :  1e-05
# user_id:  105159791   average :  0.00012
# user_id:  204252372   average :  1e-05
# user_id:  178423779   average :  2e-05
# user_id:  101777863   average :  1e-05
# user_id:  207817208   average :  1e-05
# user_id:  218405343   average :  1e-05
# user_id:  171107070   average :  1e-05
# user_id:  71318298   average :  1e-05
# user_id:  73767750   average :  1e-05
# user_id:  75064242   average :  5e-05
# user_id:  177444568   average :  0.00013
# user_id:  194196780   average :  5e-05
# user_id:  286151784   average :  3e-05
# user_id:  185218619   average :  1e-05
# user_id:  108160472   average :  0.00039
# user_id:  239045127   average :  4e-05
# user_id:  205035443   average :  1e-05
# user_id:  298884520   average :  6e-05
# user_id:  85853924   average :  1e-05
# user_id:  78814920   average :  1e-05
# user_id:  104721942   average :  9e-05
# user_id:  136561410   average :  1e-05
# user_id:  227936170   average :  1e-05
# user_id:  159994178   average :  0.00015
# user_id:  16919977   average :  3e-05
# user_id:  231333981   average :  3e-05
# user_id:  163930591   average :  0.00046
# user_id:  235185786   average :  1e-05
# user_id:  248056920   average :  1e-05
# user_id:  23337959   average :  8e-05
# user_id:  131311166   average :  1e-05
# user_id:  243306369   average :  1e-05
# user_id:  61276934   average :  2e-05
# user_id:  72009123   average :  1e-05
# user_id:  118838369   average :  0.00027
# user_id:  102066849   average :  1e-05
# user_id:  135410112   average :  1e-05
# user_id:  292748654   average :  2e-05
# user_id:  189123038   average :  8e-05
# user_id:  191780526   average :  2e-05
# user_id:  251901551   average :  1e-05
# user_id:  259878911   average :  1e-05
# user_id:  216261706   average :  2e-05
# user_id:  161663718   average :  6e-05
# user_id:  37252377   average :  1e-05
# user_id:  145834524   average :  1e-05
# user_id:  34960438   average :  3e-05
# user_id:  280497428   average :  3e-05
# user_id:  235758386   average :  7e-05
# user_id:  80384872   average :  8e-05
# user_id:  118274084   average :  5e-05
# user_id:  14906179   average :  0.00015
# user_id:  197458771   average :  2e-05
# user_id:  45592640   average :  0.00037
# user_id:  168688983   average :  1e-05
# user_id:  88626156   average :  2e-05
# user_id:  167002074   average :  1e-05
# user_id:  83955783   average :  7e-05
# user_id:  33096779   average :  5e-05
# user_id:  144532046   average :  0.00017
# user_id:  67834115   average :  1e-05
# user_id:  293578749   average :  3e-05
# user_id:  204401529   average :  0.00035
# user_id:  139181289   average :  1e-05
# user_id:  242515341   average :  4e-05
# user_id:  185826453   average :  1e-05
# user_id:  174459790   average :  9e-05
# user_id:  140708070   average :  2e-05
# user_id:  232082615   average :  2e-05
# user_id:  142433607   average :  2e-05
# user_id:  202894728   average :  7e-05
# user_id:  85497862   average :  0.00066
# user_id:  252074145   average :  5e-05
# user_id:  185781816   average :  1e-05
# user_id:  211157562   average :  1e-05
# user_id:  185907866   average :  1e-05
# user_id:  183048608   average :  7e-05
# user_id:  159844178   average :  1e-05
# user_id:  174607800   average :  1e-05
# user_id:  241206497   average :  1e-05
# user_id:  114431673   average :  2e-05
# user_id:  135522355   average :  2e-05
# user_id:  275120552   average :  1e-05
# user_id:  142044216   average :  1e-05
# user_id:  175345951   average :  2e-05
# user_id:  300041052   average :  1e-05
# user_id:  51558260   average :  5e-05
# user_id:  252675449   average :  2e-05
# user_id:  295171886   average :  1e-05
# user_id:  187477041   average :  1e-05
# user_id:  307674833   average :  2e-05
# user_id:  236210195   average :  2e-05
# user_id:  246883819   average :  2e-05
# user_id:  237525173   average :  1e-05
# user_id:  300806786   average :  1e-05
# user_id:  133169378   average :  1e-05
# user_id:  238410719   average :  2e-05
# user_id:  155283245   average :  1e-05
# user_id:  246650796   average :  1e-05
# user_id:  189640897   average :  2e-05
# user_id:  237083653   average :  1e-05
# user_id:  251287156   average :  1e-05
# user_id:  224532667   average :  2e-05
# user_id:  224754050   average :  0.00029
# user_id:  96221495   average :  1e-05
# user_id:  42469578   average :  3e-05
# user_id:  46607365   average :  9e-05
# user_id:  107698030   average :  1e-05
# user_id:  158712831   average :  1e-05
# user_id:  154687199   average :  0.00016
# user_id:  206414060   average :  1e-05
# user_id:  192134691   average :  1e-05
# user_id:  151133200   average :  1e-05
# user_id:  193599149   average :  1e-05
# user_id:  186347003   average :  1e-05
# user_id:  123334228   average :  1e-05
# user_id:  298644721   average :  2e-05
# user_id:  53244117   average :  5e-05
# user_id:  29111100   average :  5e-05
# user_id:  251732117   average :  4e-05
# user_id:  197652539   average :  0.00019
# user_id:  174991407   average :  2e-05
# user_id:  182426216   average :  4e-05
# user_id:  210700279   average :  1e-05
# user_id:  222642626   average :  2e-05
# user_id:  179822216   average :  1e-05
# user_id:  208004844   average :  3e-05
# user_id:  251635136   average :  0.00013
# user_id:  161633525   average :  1e-05
# user_id:  236476905   average :  1e-05
# user_id:  213523850   average :  6e-05
# user_id:  54739475   average :  1e-05
# user_id:  175460237   average :  2e-05
# user_id:  96269099   average :  2e-05
# user_id:  306950369   average :  1e-05
# user_id:  307705649   average :  1e-05
# user_id:  112089956   average :  2e-05
# user_id:  127947215   average :  2e-05
# user_id:  56436338   average :  4e-05
# user_id:  183983684   average :  8e-05
# user_id:  294924069   average :  1e-05
# user_id:  104192353   average :  4e-05
# user_id:  251634185   average :  6e-05
# user_id:  235227013   average :  1e-05
# user_id:  213184657   average :  1e-05
# user_id:  130431476   average :  1e-05
# user_id:  138906315   average :  1e-05
# user_id:  63605342   average :  3e-05
# user_id:  235469862   average :  1e-05
# user_id:  107951494   average :  2e-05
# user_id:  106099216   average :  5e-05
# user_id:  184938219   average :  1e-05
# user_id:  76243637   average :  1e-05
# user_id:  133964193   average :  8e-05
# user_id:  156090224   average :  1e-05
# user_id:  284701762   average :  1e-05
# user_id:  174002551   average :  0.00029
# user_id:  7923954   average :  6e-05
# user_id:  167815968   average :  0.00034
# user_id:  63655097   average :  1e-05
# user_id:  110121805   average :  1e-05
# user_id:  203631881   average :  1e-05
# user_id:  113411607   average :  1e-05
# user_id:  251884888   average :  1e-05
# user_id:  198286263   average :  1e-05
# user_id:  178236087   average :  1e-05
# user_id:  279619836   average :  1e-05
# user_id:  196724692   average :  1e-05
# user_id:  6216773   average :  2e-05
# user_id:  253502799   average :  1e-05
# user_id:  165755355   average :  0.00061
# user_id:  96030847   average :  2e-05
# user_id:  150370754   average :  1e-05
# user_id:  125371499   average :  1e-05
# user_id:  261281192   average :  3e-05
# user_id:  304908910   average :  1e-05
# user_id:  298242221   average :  2e-05
# user_id:  95699780   average :  0.00056
# user_id:  216417218   average :  1e-05
# user_id:  167417654   average :  5e-05
# user_id:  204304907   average :  1e-05
# user_id:  294551734   average :  1e-05
# user_id:  168576745   average :  1e-05
# user_id:  173179969   average :  1e-05
# user_id:  300899222   average :  1e-05
# user_id:  165071607   average :  1e-05
# user_id:  145839555   average :  1e-05
# user_id:  138818276   average :  1e-05
# user_id:  43284145   average :  0.00012
# user_id:  46951849   average :  0.00021
# user_id:  123148033   average :  1e-05
# user_id:  120589251   average :  4e-05
# user_id:  171160183   average :  5e-05
# user_id:  216608525   average :  1e-05
# user_id:  302573478   average :  2e-05
# user_id:  139832829   average :  1e-05
# user_id:  129478920   average :  2e-05
# user_id:  72978546   average :  0.00079
# user_id:  126402145   average :  1e-05
# user_id:  201728484   average :  1e-05
# user_id:  111003194   average :  1e-05
# user_id:  298452474   average :  1e-05
# user_id:  96696864   average :  8e-05
# user_id:  244156828   average :  1e-05
# user_id:  14416572   average :  2e-05
# user_id:  300928439   average :  2e-05
# user_id:  212949727   average :  1e-05
# user_id:  154208464   average :  2e-05
# user_id:  54402999   average :  2e-05
# user_id:  197166094   average :  1e-05
# user_id:  261497568   average :  1e-05
# user_id:  238891457   average :  1e-05
# user_id:  251408008   average :  1e-05
# user_id:  209161162   average :  2e-05
# user_id:  230913442   average :  2e-05
# user_id:  181716896   average :  0.00011
# user_id:  69467127   average :  1e-05
# user_id:  62486194   average :  4e-05
# user_id:  192182310   average :  1e-05
# user_id:  5860071   average :  0.00012
# user_id:  283212746   average :  1e-05
# user_id:  227020953   average :  1e-05
# user_id:  209052347   average :  1e-05
# user_id:  36910614   average :  2e-05
# user_id:  127426141   average :  0.00021
# user_id:  202376797   average :  3e-05
# user_id:  81901544   average :  2e-05
# user_id:  92103372   average :  2e-05
# user_id:  170775754   average :  1e-05
# user_id:  24841093   average :  0.00015
# user_id:  184797043   average :  1e-05
# user_id:  154174570   average :  1e-05
# user_id:  173299790   average :  1e-05
# user_id:  27168078   average :  5e-05
# user_id:  137846274   average :  9e-05
# user_id:  235587689   average :  2e-05
# user_id:  259875529   average :  1e-05
# user_id:  129117376   average :  0.00095
# user_id:  199727985   average :  1e-05
# user_id:  11080937   average :  3e-05
# user_id:  99659706   average :  1e-05
# user_id:  266972568   average :  1e-05
# user_id:  99640715   average :  2e-05
# user_id:  90866995   average :  1e-05
# user_id:  82029808   average :  5e-05
# user_id:  203712998   average :  1e-05
# user_id:  214004621   average :  1e-05
# user_id:  123734483   average :  0.00025
# user_id:  159814545   average :  1e-05
# user_id:  108591170   average :  1e-05
# user_id:  170528231   average :  1e-05
# user_id:  182329183   average :  1e-05
# user_id:  186644269   average :  1e-05
# user_id:  225495607   average :  1e-05
# user_id:  76768611   average :  1e-05
# user_id:  220561138   average :  0.00016
# user_id:  290502496   average :  2e-05
# user_id:  134224287   average :  0.00012
# user_id:  163754392   average :  1e-05
# user_id:  202018536   average :  1e-05
# user_id:  157636450   average :  0.00121
# user_id:  259796248   average :  1e-05
# user_id:  234912279   average :  1e-05
# user_id:  61274953   average :  1e-05
# user_id:  204986955   average :  2e-05
# user_id:  83806417   average :  2e-05
# user_id:  160433170   average :  2e-05
# user_id:  291482664   average :  6e-05
# user_id:  186523896   average :  1e-05
# user_id:  141315459   average :  1e-05
# user_id:  74855005   average :  0.0005
# user_id:  70338529   average :  1e-05
# user_id:  256645945   average :  6e-05
# user_id:  26302344   average :  0.00041
# user_id:  89012535   average :  2e-05
# user_id:  285478986   average :  2e-05
# user_id:  88813210   average :  2e-05
# user_id:  93963263   average :  2e-05
# user_id:  231498310   average :  2e-05
# user_id:  286935538   average :  1e-05
# user_id:  242803837   average :  1e-05
# user_id:  162894140   average :  3e-05
# user_id:  74077887   average :  1e-05
# user_id:  90304490   average :  2e-05
# user_id:  83625754   average :  0.00019
# user_id:  175471735   average :  1e-05
# user_id:  27037996   average :  2e-05
# user_id:  123029327   average :  1e-05
# user_id:  300199064   average :  1e-05
# user_id:  205753843   average :  1e-05
# user_id:  188052591   average :  2e-05
# user_id:  237153647   average :  1e-05
# user_id:  229748951   average :  2e-05
# user_id:  79658056   average :  7e-05
# user_id:  188421568   average :  5e-05
# user_id:  201708562   average :  2e-05
# user_id:  210728513   average :  2e-05
# user_id:  120520430   average :  3e-05
# user_id:  158877899   average :  7e-05
# user_id:  157887709   average :  1e-05
# user_id:  208127198   average :  3e-05
# user_id:  80098179   average :  0.00012
# user_id:  554278   average :  0.00022
# user_id:  122536802   average :  1e-05
# user_id:  163671750   average :  1e-05
# user_id:  20362352   average :  8e-05
# user_id:  714122   average :  8e-05
# user_id:  110194091   average :  5e-05
# user_id:  138228336   average :  1e-05
# user_id:  191052911   average :  1e-05
# user_id:  194641575   average :  7e-05
# user_id:  161657866   average :  2e-05
# user_id:  162631416   average :  1e-05
# user_id:  105837235   average :  1e-05
# user_id:  36856786   average :  5e-05
# user_id:  231255153   average :  9e-05
# user_id:  160288335   average :  0.00024
# user_id:  136222532   average :  1e-05
# user_id:  181666776   average :  7e-05
# user_id:  84703874   average :  1e-05
# user_id:  203492188   average :  1e-05
# user_id:  231221037   average :  1e-05
# user_id:  231210957   average :  1e-05
# user_id:  183288699   average :  1e-05
# user_id:  228541607   average :  1e-05
# user_id:  35418544   average :  1e-05
# user_id:  58893462   average :  5e-05
# user_id:  170068207   average :  0.00042
# user_id:  117463647   average :  1e-05
# user_id:  292741048   average :  6e-05
# user_id:  88492781   average :  1e-05
# user_id:  159283849   average :  1e-05
# user_id:  238700575   average :  0.00015
# user_id:  199664148   average :  1e-05
# user_id:  178242321   average :  1e-05
# user_id:  149810726   average :  0.00012
# user_id:  152597701   average :  1e-05
# user_id:  161339015   average :  1e-05
# user_id:  189675274   average :  1e-05
# user_id:  78142481   average :  2e-05
# user_id:  80173910   average :  2e-05
# user_id:  70930091   average :  3e-05
# user_id:  208433656   average :  1e-05
# user_id:  79615216   average :  2e-05
# user_id:  119835248   average :  2e-05
# user_id:  97659219   average :  5e-05
# user_id:  222008249   average :  0.0001
# user_id:  186167611   average :  4e-05
# user_id:  204477246   average :  0.00012
# user_id:  149579610   average :  4e-05
# user_id:  214914991   average :  1e-05
# user_id:  107107474   average :  2e-05
# user_id:  200657041   average :  1e-05
# user_id:  260017289   average :  2e-05
# user_id:  187499055   average :  1e-05
# user_id:  204970557   average :  1e-05
# user_id:  10095386   average :  3e-05
# user_id:  38179194   average :  0.00012
# user_id:  95084569   average :  0.00021
# user_id:  246258933   average :  0.00011
# user_id:  175450855   average :  2e-05
# user_id:  216227311   average :  2e-05
# user_id:  172203679   average :  2e-05
# user_id:  8567888   average :  9e-05
# user_id:  5990132   average :  0.00041
# user_id:  107476377   average :  0.0001
# user_id:  183838531   average :  0.00012
# user_id:  40044821   average :  1e-05
# user_id:  207915392   average :  0.00015
# user_id:  35047392   average :  7e-05
# user_id:  144736   average :  6e-05
# user_id:  127261069   average :  2e-05
# user_id:  262133376   average :  2e-05
# user_id:  204453243   average :  1e-05
# user_id:  18263482   average :  8e-05
# user_id:  83770731   average :  0.0013
# user_id:  98308239   average :  2e-05
# user_id:  171265504   average :  2e-05
# user_id:  82287546   average :  0.00076
# user_id:  114727578   average :  0.0009
# user_id:  134282559   average :  1e-05
# user_id:  292129258   average :  1e-05
# user_id:  156202123   average :  2e-05
# user_id:  130810920   average :  1e-05
# user_id:  49880470   average :  1e-05
# user_id:  84884010   average :  2e-05
# user_id:  61506984   average :  1e-05
# user_id:  166243691   average :  1e-05
# user_id:  292744287   average :  0.00017
# user_id:  178312427   average :  1e-05
# user_id:  170048045   average :  1e-05
# user_id:  39319649   average :  0.0002
# user_id:  244648789   average :  2e-05
# user_id:  101596530   average :  0.00067
# user_id:  231914521   average :  1e-05
# user_id:  182020275   average :  1e-05
# user_id:  241636947   average :  1e-05
# user_id:  201196839   average :  1e-05
# user_id:  94610298   average :  1e-05
# user_id:  108114779   average :  0.00019
# user_id:  30912860   average :  0.00084
# user_id:  228620097   average :  1e-05
# user_id:  121891688   average :  8e-05
# user_id:  154274745   average :  1e-05
# user_id:  284604128   average :  1e-05
# user_id:  170557064   average :  1e-05
# user_id:  198464515   average :  2e-05
# user_id:  158952821   average :  2e-05
# user_id:  155919035   average :  0.00167
# user_id:  30561172   average :  2e-05
# user_id:  154374262   average :  5e-05
# user_id:  206436717   average :  2e-05
# user_id:  173256445   average :  1e-05
# user_id:  217660785   average :  2e-05
# user_id:  123449538   average :  1e-05
# user_id:  71449134   average :  2e-05
# user_id:  167460926   average :  1e-05
# user_id:  33659046   average :  0.00025
# user_id:  156818121   average :  0.00063
# user_id:  145710414   average :  1e-05
# user_id:  97604502   average :  4e-05
# user_id:  105632759   average :  2e-05
# user_id:  14126086   average :  0.00096
# user_id:  194191204   average :  5e-05
# user_id:  59662830   average :  0.00137
# user_id:  193087158   average :  5e-05
# user_id:  212660921   average :  5e-05
# user_id:  212636691   average :  1e-05
# user_id:  29736184   average :  5e-05
# user_id:  124723151   average :  1e-05
# user_id:  22088241   average :  5e-05
# user_id:  119530092   average :  8e-05
# user_id:  306617101   average :  2e-05
# user_id:  253675435   average :  1e-05
# user_id:  228766741   average :  1e-05
# user_id:  297492378   average :  1e-05
# user_id:  105052833   average :  1e-05
# user_id:  106472745   average :  1e-05
# user_id:  258868457   average :  1e-05
# user_id:  248200343   average :  1e-05
# user_id:  211421471   average :  4e-05
# user_id:  308503685   average :  1e-05
# user_id:  298417849   average :  1e-05
# user_id:  147910240   average :  5e-05
# user_id:  159458198   average :  4e-05
# user_id:  241626039   average :  2e-05
# user_id:  60910490   average :  2e-05
# user_id:  162747179   average :  3e-05
# user_id:  30061970   average :  0.00073
# user_id:  176645108   average :  3e-05
# user_id:  86433707   average :  0.00015
# user_id:  86738567   average :  0.00019
# user_id:  71161460   average :  1e-05
# user_id:  211191233   average :  2e-05
# user_id:  151256632   average :  0.00016
# user_id:  53621752   average :  8e-05
# user_id:  31187179   average :  0.00084
# user_id:  39223571   average :  1e-05
# user_id:  229900582   average :  1e-05
# user_id:  168771588   average :  9e-05
# user_id:  255246635   average :  1e-05
# user_id:  106268266   average :  1e-05
# user_id:  305019410   average :  1e-05
# user_id:  111163130   average :  0.00029
# user_id:  50269563   average :  1e-05
# user_id:  266132392   average :  1e-05
# user_id:  303413869   average :  1e-05
# user_id:  92123735   average :  2e-05
# user_id:  5217749   average :  9e-05
# user_id:  47773209   average :  5e-05
# user_id:  122552077   average :  1e-05
# user_id:  208569224   average :  2e-05
# user_id:  190774375   average :  1e-05
# user_id:  132277897   average :  2e-05
# user_id:  93458820   average :  1e-05
# user_id:  192044880   average :  4e-05
# user_id:  238666183   average :  1e-05
# user_id:  172699566   average :  1e-05
# user_id:  287778700   average :  2e-05
# user_id:  174121221   average :  1e-05
# user_id:  155669429   average :  2e-05
# user_id:  12563913   average :  6e-05
# user_id:  215687170   average :  1e-05
# user_id:  138939472   average :  1e-05
# user_id:  295436578   average :  1e-05
# ...
# user_id:  199659716   average :  0.00015
# user_id:  91807066   average :  0.00034
# user_id:  220999682   average :  1e-05
# user_id:  136190090   average :  1e-05
# user_id:  125472731   average :  0.0001
# user_id:  156303898   average :  2e-05
# user_id:  224844255   average :  1e-05
# user_id:  92965596   average :  8e-05
# user_id:  195442852   average :  1e-05
# user_id:  180064841   average :  2e-05
# user_id:  274538592   average :  1e-05
# user_id:  105071117   average :  3e-05
# user_id:  86073747   average :  1e-05
# user_id:  72098561   average :  1e-05
# user_id:  14671378   average :  0.00021
# user_id:  287500646   average :  1e-05
# user_id:  130678525   average :  2e-05
# user_id:  125682446   average :  0.00032
# user_id:  293288238   average :  1e-05
# user_id:  260140697   average :  1e-05
# user_id:  190687978   average :  1e-05
# user_id:  16231773   average :  0.0001
# user_id:  210109243   average :  2e-05
# user_id:  80821544   average :  1e-05
# user_id:  242973261   average :  1e-05
# user_id:  237704278   average :  8e-05
# user_id:  240368610   average :  1e-05
# user_id:  137747562   average :  1e-05
# user_id:  132708032   average :  1e-05
# user_id:  193456517   average :  1e-05
# user_id:  301737953   average :  1e-05
# user_id:  73532539   average :  2e-05
# user_id:  191576449   average :  0.00016
# user_id:  22865756   average :  8e-05
# user_id:  176684532   average :  6e-05
# user_id:  178003047   average :  0.00013
# user_id:  56818301   average :  2e-05
# user_id:  199931153   average :  8e-05
# user_id:  117720079   average :  2e-05
# user_id:  122118929   average :  1e-05
# user_id:  302166520   average :  1e-05
# user_id:  147066117   average :  2e-05
# user_id:  195354965   average :  1e-05
# user_id:  36404933   average :  0.00283
# user_id:  209023275   average :  0.00012
# user_id:  179347474   average :  0.00022
# user_id:  33658023   average :  2e-05
# user_id:  104198014   average :  2e-05
# user_id:  182464505   average :  2e-05
# user_id:  99711581   average :  8e-05
# user_id:  44085899   average :  1e-05
# user_id:  303918601   average :  2e-05
# user_id:  306931395   average :  1e-05
# user_id:  194101597   average :  2e-05
# user_id:  243783947   average :  1e-05
# user_id:  222182106   average :  1e-05
# user_id:  235901589   average :  1e-05
# user_id:  165073598   average :  0.00034
# user_id:  141103096   average :  1e-05
# user_id:  154533830   average :  0.00023
# user_id:  130299876   average :  2e-05
# user_id:  44231506   average :  3e-05
# user_id:  222867863   average :  3e-05
# user_id:  203643703   average :  5e-05
# user_id:  110104315   average :  1e-05
# user_id:  10064100   average :  3e-05
# user_id:  11718802   average :  5e-05
# user_id:  299450273   average :  1e-05
# user_id:  173841416   average :  1e-05
# user_id:  268934736   average :  2e-05
# user_id:  179798677   average :  1e-05
# user_id:  281437808   average :  1e-05
# user_id:  79319075   average :  0.00016
# user_id:  72293974   average :  1e-05
# user_id:  120668831   average :  3e-05
# user_id:  34972055   average :  1e-05
# user_id:  231416829   average :  0.0002
# user_id:  185484994   average :  1e-05
# user_id:  171900219   average :  1e-05
# user_id:  96634230   average :  1e-05
# user_id:  131473057   average :  6e-05
# user_id:  186090773   average :  1e-05
# user_id:  976129   average :  6e-05
# user_id:  93030550   average :  0.00012
# user_id:  93405380   average :  1e-05
# user_id:  33452361   average :  0.00014
# user_id:  56840402   average :  4e-05
# user_id:  259311761   average :  2e-05
# user_id:  175941533   average :  7e-05
# user_id:  171893056   average :  1e-05
# user_id:  89691468   average :  0.00029
# user_id:  251085489   average :  1e-05
# user_id:  42454699   average :  1e-05
# user_id:  53097340   average :  0.00093
# user_id:  224493107   average :  1e-05
# user_id:  245023643   average :  2e-05
# user_id:  112509160   average :  1e-05
# user_id:  95519970   average :  1e-05
# user_id:  156831526   average :  3e-05
# user_id:  47144509   average :  2e-05
# user_id:  208838704   average :  4e-05
# user_id:  118360669   average :  1e-05
# user_id:  139074732   average :  1e-05
# user_id:  20772968   average :  0.00459
# user_id:  205633878   average :  1e-05
# user_id:  163073929   average :  1e-05
# user_id:  28608870   average :  2e-05
# user_id:  180407911   average :  1e-05
# user_id:  159651274   average :  1e-05
# user_id:  213854339   average :  3e-05
# user_id:  39146470   average :  0.00041
# user_id:  27925556   average :  5e-05
# user_id:  130931340   average :  1e-05
# user_id:  129647095   average :  1e-05
# user_id:  245352892   average :  2e-05
# user_id:  251197403   average :  2e-05
# user_id:  47384303   average :  0.00117
# user_id:  110174573   average :  2e-05
# user_id:  132191842   average :  1e-05
# user_id:  181576759   average :  1e-05
# user_id:  250159880   average :  1e-05
# user_id:  177213985   average :  0.00013
# user_id:  114838001   average :  0.00032
# user_id:  240046261   average :  1e-05
# user_id:  208519728   average :  1e-05
# user_id:  276090576   average :  0.00014
# user_id:  250988060   average :  3e-05
# user_id:  12897088   average :  3e-05
# user_id:  25831175   average :  5e-05
# user_id:  238511591   average :  1e-05
# user_id:  269123804   average :  1e-05
# user_id:  38885272   average :  2e-05
# user_id:  186134916   average :  2e-05
# user_id:  142409681   average :  3e-05
# user_id:  259854084   average :  2e-05
# user_id:  107417121   average :  3e-05
# user_id:  225637918   average :  1e-05
# user_id:  160965612   average :  7e-05
# user_id:  66755246   average :  0.00015
# user_id:  76211030   average :  4e-05
# user_id:  120514307   average :  8e-05
# user_id:  244335912   average :  7e-05
# user_id:  203332508   average :  1e-05
# user_id:  268245436   average :  1e-05
# user_id:  39227796   average :  2e-05
# user_id:  194872360   average :  6e-05
# user_id:  142591675   average :  2e-05
# user_id:  210656814   average :  1e-05
# user_id:  257081520   average :  1e-05
# user_id:  274420264   average :  1e-05
# user_id:  245306716   average :  1e-05
# user_id:  107124497   average :  8e-05
# user_id:  204014532   average :  9e-05
# user_id:  283382726   average :  4e-05
# user_id:  80511960   average :  0.00054
# user_id:  17284266   average :  0.00012
# user_id:  210771203   average :  1e-05
# user_id:  198962605   average :  1e-05
# user_id:  55944717   average :  2e-05
# user_id:  302394761   average :  9e-05
# user_id:  161411713   average :  1e-05
# user_id:  216154835   average :  2e-05
# user_id:  68240622   average :  0.00012
# user_id:  214425734   average :  1e-05
# user_id:  120342002   average :  2e-05
# user_id:  181900480   average :  3e-05
# user_id:  98663937   average :  1e-05
# user_id:  193103684   average :  0.00073
# user_id:  254739428   average :  2e-05
# user_id:  272300684   average :  2e-05
# user_id:  205995905   average :  2e-05
# user_id:  192861545   average :  5e-05
# user_id:  191377488   average :  3e-05
# user_id:  33023846   average :  2e-05
# user_id:  238858519   average :  2e-05
# user_id:  218668551   average :  1e-05
# user_id:  92904111   average :  4e-05
# user_id:  92276000   average :  0.00027
# user_id:  94675519   average :  1e-05
# user_id:  48666962   average :  0.00028
# user_id:  199500064   average :  3e-05
# user_id:  178144284   average :  2e-05
# user_id:  234286554   average :  5e-05
# user_id:  100818860   average :  9e-05
# user_id:  45459546   average :  3e-05
# user_id:  209783211   average :  2e-05
# user_id:  139574442   average :  1e-05
# user_id:  215769135   average :  1e-05
# user_id:  59773143   average :  8e-05
# user_id:  219775534   average :  3e-05
# user_id:  62666911   average :  2e-05
# user_id:  140086587   average :  6e-05
# user_id:  14421986   average :  6e-05
# user_id:  198605042   average :  0.00011
# user_id:  209218938   average :  1e-05
# user_id:  295726552   average :  1e-05
# user_id:  106340092   average :  1e-05
# user_id:  208799740   average :  1e-05
# user_id:  226657630   average :  1e-05
# user_id:  83148759   average :  7e-05
# user_id:  59854456   average :  3e-05
# user_id:  186287462   average :  4e-05
# user_id:  294123013   average :  2e-05
# user_id:  221325014   average :  1e-05
# user_id:  234779342   average :  1e-05
# user_id:  185959000   average :  2e-05
# user_id:  193553590   average :  1e-05
# user_id:  237799851   average :  1e-05
# user_id:  285869008   average :  0.0001
# user_id:  92669869   average :  2e-05
# user_id:  183294889   average :  9e-05
# user_id:  177406869   average :  1e-05
# user_id:  158429732   average :  7e-05
# user_id:  295809791   average :  1e-05
# user_id:  273624636   average :  1e-05
# user_id:  56470008   average :  2e-05
# user_id:  240832135   average :  1e-05
# user_id:  112845094   average :  0.00031
# user_id:  228412369   average :  2e-05
# user_id:  225566535   average :  1e-05
# user_id:  238016355   average :  1e-05
# user_id:  265619532   average :  2e-05
# user_id:  158876958   average :  1e-05
# user_id:  255615919   average :  1e-05
# user_id:  299510506   average :  2e-05
# user_id:  137651115   average :  5e-05
# user_id:  91597624   average :  2e-05
# user_id:  16261218   average :  3e-05
# user_id:  249540800   average :  1e-05
# user_id:  254550709   average :  0.00018
# user_id:  622362   average :  8e-05
# user_id:  158828239   average :  3e-05
# user_id:  157314597   average :  5e-05
# user_id:  209126665   average :  2e-05
# user_id:  238640566   average :  1e-05
# user_id:  44043970   average :  3e-05
# user_id:  247042500   average :  2e-05
# user_id:  101530848   average :  0.00028
# user_id:  186867770   average :  1e-05
# user_id:  106147639   average :  2e-05
# user_id:  264626784   average :  0.00015
# user_id:  95924900   average :  4e-05
# user_id:  107273897   average :  0.00015
# user_id:  96355913   average :  1e-05
# user_id:  178698811   average :  2e-05
# user_id:  117345810   average :  0.00059
# user_id:  33614428   average :  5e-05
# user_id:  99133844   average :  0.00012
# user_id:  290582378   average :  2e-05
# user_id:  28731346   average :  5e-05
# user_id:  33362395   average :  2e-05
# user_id:  81943620   average :  0.00232
# user_id:  80265154   average :  4e-05
# user_id:  193581345   average :  1e-05
# user_id:  65076545   average :  2e-05
# user_id:  237022317   average :  8e-05
# user_id:  238220798   average :  2e-05
# user_id:  293101422   average :  1e-05
# user_id:  94396146   average :  1e-05
# user_id:  70180527   average :  7e-05
# user_id:  53784377   average :  5e-05
# user_id:  138958592   average :  2e-05
# user_id:  73761548   average :  1e-05
# user_id:  94931090   average :  2e-05
# user_id:  156407373   average :  0.00026
# user_id:  283111528   average :  2e-05
# user_id:  202700087   average :  2e-05
# user_id:  213422095   average :  1e-05
# user_id:  217485443   average :  1e-05
# user_id:  210076971   average :  1e-05
# user_id:  305130721   average :  2e-05
# user_id:  85673716   average :  0.00019
# user_id:  281084246   average :  2e-05
# user_id:  231591025   average :  1e-05
# user_id:  171216006   average :  1e-05
# user_id:  206896748   average :  2e-05
# user_id:  195559468   average :  1e-05
# user_id:  230626371   average :  1e-05
# user_id:  126690600   average :  1e-05
# user_id:  269853648   average :  1e-05
# user_id:  158762452   average :  1e-05
# user_id:  129364343   average :  0.0001
# user_id:  213256245   average :  1e-05
# user_id:  173026047   average :  1e-05
# user_id:  309265377   average :  2e-05
# user_id:  111202525   average :  4e-05
# user_id:  203370502   average :  1e-05
# user_id:  137398114   average :  1e-05
# user_id:  90277291   average :  1e-05
# user_id:  152581137   average :  1e-05
# user_id:  25411448   average :  5e-05
# user_id:  248376475   average :  2e-05
# user_id:  248507053   average :  1e-05
# user_id:  202843172   average :  7e-05
# user_id:  100412579   average :  1e-05
# user_id:  237696689   average :  1e-05
# user_id:  222180483   average :  0.00019
# user_id:  170198088   average :  9e-05
# user_id:  174507916   average :  0.0001
# user_id:  3979930   average :  0.00021
# user_id:  182593346   average :  1e-05
# user_id:  283651572   average :  2e-05
# user_id:  160767652   average :  9e-05
# user_id:  107623882   average :  4e-05
# user_id:  280457098   average :  1e-05
# user_id:  94229851   average :  8e-05
# user_id:  135698781   average :  2e-05
# user_id:  20266830   average :  5e-05
# user_id:  126294907   average :  1e-05
# user_id:  298008741   average :  1e-05
# user_id:  70395325   average :  1e-05
# user_id:  133313288   average :  1e-05
# user_id:  60859695   average :  0.00151
# user_id:  159531216   average :  2e-05
# user_id:  122529449   average :  1e-05
# user_id:  75970863   average :  7e-05
# user_id:  71331921   average :  0.00019
# user_id:  42657809   average :  0.00122
# user_id:  168686827   average :  1e-05
# user_id:  154230723   average :  0.00319
# user_id:  149434889   average :  1e-05
# user_id:  87201181   average :  0.00039
# user_id:  253245972   average :  1e-05
# user_id:  192616228   average :  1e-05
# user_id:  232257053   average :  1e-05
# user_id:  23181958   average :  5e-05
# user_id:  258673767   average :  3e-05
# user_id:  161013852   average :  0.00033
# user_id:  147879598   average :  8e-05
# user_id:  212090589   average :  1e-05
# user_id:  31385451   average :  5e-05
# user_id:  138590829   average :  1e-05
# user_id:  190460990   average :  1e-05
# user_id:  84026704   average :  1e-05
# user_id:  30503921   average :  1e-05
# user_id:  112739159   average :  1e-05
# user_id:  7519923   average :  2e-05
# user_id:  308997600   average :  1e-05
# user_id:  97578013   average :  1e-05
# user_id:  138542725   average :  2e-05
# user_id:  42326526   average :  1e-05
# user_id:  294006204   average :  2e-05
# user_id:  98653215   average :  1e-05
# user_id:  245839900   average :  2e-05
# user_id:  144319593   average :  1e-05
# user_id:  224601141   average :  1e-05
# user_id:  116564064   average :  0.00139
# user_id:  41124938   average :  1e-05
# user_id:  210045073   average :  1e-05
# user_id:  251065129   average :  2e-05
# user_id:  55162535   average :  2e-05
# user_id:  172752250   average :  1e-05
# user_id:  58794630   average :  3e-05
# user_id:  103963922   average :  1e-05
# user_id:  229229843   average :  1e-05
# user_id:  127475581   average :  1e-05
# user_id:  147444403   average :  1e-05
# user_id:  112148863   average :  2e-05
# user_id:  106806354   average :  1e-05
# user_id:  34901647   average :  0.0009
# user_id:  65729155   average :  5e-05
# user_id:  25889289   average :  3e-05
# user_id:  191721546   average :  2e-05
# user_id:  90878103   average :  2e-05
# user_id:  246925775   average :  2e-05
# user_id:  72417734   average :  0.00017
# user_id:  235723933   average :  2e-05
# user_id:  164796966   average :  1e-05
# user_id:  105080654   average :  1e-05
# user_id:  204041850   average :  1e-05
# user_id:  233568555   average :  2e-05
# user_id:  83965474   average :  2e-05
# user_id:  156423928   average :  1e-05
# user_id:  205897759   average :  1e-05
# user_id:  304834885   average :  2e-05
# user_id:  262752300   average :  2e-05
# user_id:  227863398   average :  2e-05
# user_id:  273293320   average :  4e-05
# user_id:  122189475   average :  1e-05
# user_id:  49759696   average :  1e-05
# user_id:  154145611   average :  0.00015
# user_id:  111362598   average :  0.00035
# user_id:  34442062   average :  0.00013
# user_id:  233726801   average :  8e-05
# user_id:  151600301   average :  0.00026
# user_id:  184620075   average :  1e-05
# user_id:  154531790   average :  1e-05
# user_id:  73726855   average :  0.001
# user_id:  204967665   average :  2e-05
# user_id:  161896440   average :  0.00034
# user_id:  215721461   average :  3e-05
# user_id:  289760650   average :  2e-05
# user_id:  294201005   average :  1e-05
# user_id:  169427688   average :  1e-05
# user_id:  295386628   average :  1e-05
# user_id:  300991661   average :  1e-05
# user_id:  135400225   average :  0.00143
# user_id:  131377772   average :  3e-05
# user_id:  88705345   average :  0.00015
# user_id:  274261412   average :  2e-05
# user_id:  231947531   average :  1e-05
# user_id:  188089669   average :  1e-05
# user_id:  68081395   average :  1e-05
# user_id:  205881130   average :  1e-05
# user_id:  288160158   average :  1e-05
# user_id:  125424716   average :  0.0001
# user_id:  99096740   average :  0.00022
# user_id:  176449171   average :  6e-05
# user_id:  221315846   average :  3e-05
# user_id:  128470551   average :  0.00012
